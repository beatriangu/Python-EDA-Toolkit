# %%
# !pip install git+https://github.com/beatriangu/Python-EDA-Toolkit.git
# Out:
# ...
#   Cloning https://github.com/beatriangu/Python-EDA-Toolkit.git to /private/var/folders/w3/541cg4z537515pp5__trjl7c0000gn/T/pip-req-build-ud2tnzva
#   Running command git clone --filter=blob:none --quiet https://github.com/beatriangu/Python-EDA-Toolkit.git /private/var/folders/w3/541cg4z537515pp5__trjl7c0000gn/T/pip-req-build-ud2tnzva
#   Resolved https://github.com/beatriangu/Python-EDA-Toolkit.git to commit 880128bdcf10cdf81836fbe4c2d1dcca4467aed3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for python-eda-toolkit: filename=python_eda_toolkit-0.1.0-py3-none-any.whl size=6116 sha256=68f401575dc33301563c884e752365a2f01255b4db6250ff81224162f9efab66
#   Stored in directory: /private/var/folders/w3/541cg4z537515pp5__trjl7c0000gn/T/pip-ephem-wheel-cache-6urmugus/wheels/09/f7/7b/b53e5adc31c61f553272b7264ca994b877e828dbb34399c0df
# Successfully built python-eda-toolkit
# ...
